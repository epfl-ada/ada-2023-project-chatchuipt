# %% [markdown]
# # Project milestone 2
#
# ## Libraries
# *To run the notebook install all these packages using pip install <name_package>*
# - pandas
# - numpy
# - matplotlib
# - seaborn
# - pickle
# - folium
# - geopy
# - IPyhton
# - statsmodels
# - sklearn.linear_model
#
# ## Data
# This dataset consists of beer reviews from two Beer rating websites: BeerAdvocate and RateBeer, for a period of 17 years ranging from 2001 to 2017.
#
# ## Idea of project
# This project aims mainly at studying the beer trends based on seasons. In fact, each individual may tend to consume different beers based on its mood or feeling influenced by the season.

# %% [markdown]
# **Import libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import folium
from geopy.geocoders import Nominatim
from IPython.display import display
import statsmodels.api as sm
from statsmodels.tsa.seasonal import STL
from sklearn.linear_model import LinearRegression, LogisticRegression, Ridge

# %% [markdown]
# **Import first datasets**

# %%
FOLDER_BA = './BeerAdvocate/'
beers_ba = pd.read_csv(FOLDER_BA + 'beers.csv')
breweries_ba = pd.read_csv(FOLDER_BA + 'breweries.csv')
users_ba = pd.read_csv(FOLDER_BA + 'users.csv')

FOLDER_RB = './RateBeer/'
beers_rb = pd.read_csv(FOLDER_RB + 'beers.csv')
breweries_rb = pd.read_csv(FOLDER_RB + 'breweries.csv')
users_rb = pd.read_csv(FOLDER_RB + 'users.csv')

# %% [markdown]
# **Converting .txt to .csv** (make sure to have a 8 Go of RAM)

# %% [markdown]
# **Import ratings datasets (do it only once! Afterwards, directly go to 'Load cached data')**

# %%
ratings_ba_csv = pd.read_csv(FOLDER_BA + 'ratings_ba_clean.csv')

# %%
ratings_rb_csv = pd.read_csv(FOLDER_RB + 'ratings_rb_clean.csv')

# %% [markdown]
# As these files are relatively heavy, we are going to save them in cache memory, so the loading time will not be too long

# %% [markdown]
# **Cache the data**

# %%
pickle.dump(ratings_ba_csv, open('ratings_ba.pkl', 'wb'))

# %%
pickle.dump(ratings_rb_csv, open('ratings_rb.pkl', 'wb'))

# %% [markdown]
# ## 0. Load the cached data

# %%
# Load data from 'ratings_ba.pkl' & 'ratings_rb.pkl' file
ratings_ba = pickle.load(open('ratings_ba.pkl', 'rb'))
ratings_rb = pickle.load(open('ratings_rb.pkl', 'rb'))

# %% [markdown]
# ## 1. Pre-processing datasets for BeerAdvocate and RateBeer

# %%
ratings_rb.head(1)
# Out:
#    Unnamed: 0          beer_name  beer_id brewery_name  brewery_id  \
# 0           0  33 Export (Gabon)   410549      Sobraga        3198
#
#         style  abv        date user_name  user_id  appearance  aroma  palate  \
# 0  Pale Lager  5.0  1461664800   Manslow   175852           2      4       2
#
#    taste  overall  rating                                               text
# 0      4        8     2.0  Puszka 0,33l dzięki Christoph . Kolor jasnozło...

# %%
users_rb.head(1)
# Out:
#    nbr_ratings  user_id user_name        joined location
# 0         1890   175852   Manslow  1.337508e+09   Poland

# %% [markdown]
# **1.1 Merge users and ratings to obtain location of each rating especially**

# %%
# merge by a *right join*, 'user' dataframe & 'rating' dataframe based on the 'user_id' column
# the matching rows from the 'users' DataFrame will be included on all rows from the 'ratings' dataframe
user_ratings_ba = users_ba.merge(ratings_ba, how = 'right', on = 'user_id')
user_ratings_rb= users_rb.merge(ratings_rb, how = 'right', on = 'user_id')

# %%
print(user_ratings_ba.shape, user_ratings_rb.shape)
# Out:
# (8393032, 23) (7123806, 21)

# %%
user_ratings_ba.head(1)
# Out:
#    nbr_ratings  nbr_reviews         user_id user_name_x        joined  \
# 0         7820          465  nmann08.184925     nmann08  1.199704e+09
#
#                     location  Unnamed: 0 beer_name  beer_id  \
# 0  United States, Washington           0     Régab   142544
#
#                                 brewery_name  ...        date user_name_y  \
# 0  Societe des Brasseries du Gabon (SOBRAGA)  ...  1440064800     nmann08
#
#    appearance  aroma palate  taste  overall  rating  \
# 0        3.25   2.75   3.25   2.75      3.0    2.88
#
#                                                 text  review
# 0  From a bottle, pours a piss yellow color with ...    True
#
# [1 rows x 23 columns]

# %%
user_ratings_rb.head(1)
# Out:
#    nbr_ratings  user_id user_name_x        joined location  Unnamed: 0  \
# 0       1890.0   175852     Manslow  1.337508e+09   Poland           0
#
#            beer_name  beer_id brewery_name  brewery_id  ...  abv        date  \
# 0  33 Export (Gabon)   410549      Sobraga        3198  ...  5.0  1461664800
#
#    user_name_y appearance  aroma  palate  taste  overall  rating  \
# 0      Manslow          2      4       2      4        8     2.0
#
#                                                 text
# 0  Puszka 0,33l dzięki Christoph . Kolor jasnozło...
#
# [1 rows x 21 columns]

# %% [markdown]
# **1.2 Change the date format and isolate month and year**

# %%
user_ratings_ba['date'] = pd.to_datetime(user_ratings_ba['date'], unit='s')
user_ratings_rb['date'] = pd.to_datetime(user_ratings_rb['date'], unit='s')

# %%
user_ratings_ba['joined'] = pd.to_datetime(user_ratings_ba['joined'], unit='s')
user_ratings_rb['joined'] = pd.to_datetime(user_ratings_rb['joined'], unit='s')

# %%
user_ratings_ba['date'].head()
# Out:
# 0   2015-08-20 10:00:00
# 1   2009-02-20 11:00:00
# 2   2006-03-13 11:00:00
# 3   2004-12-01 11:00:00
# 4   2004-08-30 10:00:00
# Name: date, dtype: datetime64[ns]

# %%
# add columns 'month' & 'year' & 'year_month' on 'user_ratings' dataframe
user_ratings_ba['month'] = user_ratings_ba['date'].dt.month
user_ratings_ba['year'] = user_ratings_ba['date'].dt.year
user_ratings_rb['month'] = user_ratings_rb['date'].dt.month
user_ratings_rb['year'] = user_ratings_rb['date'].dt.year

# %%
user_ratings_ba['year_month'] = user_ratings_ba['date'].dt.to_period('M')
user_ratings_rb['year_month'] = user_ratings_rb['date'].dt.to_period('M')

# %% [markdown]
# ## 2. Data Cleaning
# **2.1 Remove unrelevant columns/duplicates**

# %%
user_ratings_ba.drop(['Unnamed: 0', 'user_name_y'], axis = 1, inplace = True)
user_ratings_rb.drop(['Unnamed: 0', 'user_name_y'], axis = 1, inplace = True)

# %%
user_ratings_ba.rename(columns = {'user_name_x': 'user_name'}, inplace = True)
user_ratings_rb.rename(columns = {'user_name_x': 'user_name'}, inplace = True)

# %% [markdown]
# **2.2 Identification of columns that have missing values**

# %%
user_ratings_ba.columns[user_ratings_ba.isna().any()].tolist()
# Out:
# ['user_name',
#  'joined',
#  'location',
#  'abv',
#  'appearance',
#  'aroma',
#  'palate',
#  'taste',
#  'overall',
#  'text']

# %%
user_ratings_rb.columns[user_ratings_rb.isna().any()].tolist()
# Out:
# ['nbr_ratings', 'user_name', 'joined', 'location', 'abv', 'text']

# %% [markdown]
# **2.3 Replace abv (alcohol degree) missing values by the average abv of the corresponding beer style**

# %%
# to chg ?
missing_values_abv_ba = 100 * user_ratings_ba['abv'].isna().sum() / user_ratings_ba.shape[0]
missing_values_abv_rb = 100 * user_ratings_rb['abv'].isna().sum() / user_ratings_rb.shape[0]

# %%
print(f"users_ratings_ba has {missing_values_abv_ba:.2f}% missing values in abv")
print(f"users_ratings_rb has {missing_values_abv_rb:.2f}% missing values in abv")
# Out:
# users_ratings_ba has 2.04% missing values in abv
# users_ratings_rb has 2.46% missing values in abv

# %%
style_mean_abv_ba = user_ratings_ba.groupby('style')['abv'].transform('mean')
user_ratings_ba['abv'].fillna(style_mean_abv_ba, inplace=True)

# %%
style_mean_abv_rb = user_ratings_rb.groupby('style')['abv'].transform('mean')
user_ratings_rb['abv'].fillna(style_mean_abv_rb, inplace=True)

# %% [markdown]
# **2.4 Drop NaN for location -> remove ratings where location is not mentioned**

# %%
missing_values_location_ba = 100 * user_ratings_ba['location'].isna().sum() / user_ratings_ba.shape[0]
missing_values_location_rb = 100 * user_ratings_rb['location'].isna().sum() / user_ratings_rb.shape[0]

# %%
print(f"users_ratings_ba has {missing_values_location_ba:.2f}% missing values in location")
print(f"users_ratings_rb has {missing_values_location_rb:.2f}% missing values in location")
# Out:
# users_ratings_ba has 5.96% missing values in location
# users_ratings_rb has 2.86% missing values in location

# %%
user_ratings_ba.columns
# Out:
# Index(['nbr_ratings', 'nbr_reviews', 'user_id', 'user_name', 'joined',
#        'location', 'beer_name', 'beer_id', 'brewery_name', 'brewery_id',
#        'style', 'abv', 'date', 'appearance', 'aroma', 'palate', 'taste',
#        'overall', 'rating', 'text', 'review', 'month', 'year', 'year_month'],
#       dtype='object')

# %%
type(user_ratings_ba['location'])
# Out:
# pandas.core.series.Series

# %%
user_ratings_ba = user_ratings_ba.dropna(subset=['location'])
user_ratings_rb = user_ratings_rb.dropna(subset=['location'])

# %% [markdown]
# ### 3. Compare RateBeers and BeerAdvocate

# %% [markdown]
# **3.1 Distribution of ratings and reviews between BeerAdvocate and RateBeer**

# %%
users_rb.head(3)
# Out:
#    nbr_ratings  user_id     user_name        joined location
# 0         1890   175852       Manslow  1.337508e+09   Poland
# 1           89   442761  MAGICuenca91  1.484046e+09    Spain
# 2          169   288889        Sibarh  1.384600e+09   Poland

# %%
users_ba.head(3)
# Out:
#    nbr_ratings  nbr_reviews             user_id    user_name        joined  \
# 0         7820          465      nmann08.184925      nmann08  1.199704e+09
# 1         2521         2504  stjamesgate.163714  StJamesGate  1.191838e+09
# 2         1797         1143       mdagnew.19527      mdagnew  1.116410e+09
#
#                     location
# 0  United States, Washington
# 1    United States, New York
# 2           Northern Ireland

# %%
#To chg
plt.figure(figsize=(10, 6))
plt.hist(users_rb['nbr_ratings'], label = 'RateBeer', bins=30, edgecolor='k', alpha=0.7, log=True)
plt.hist(users_ba['nbr_ratings'], label = 'BeerAdvocate', bins=30, edgecolor='k', alpha=0.7, log=True)
plt.title('Distribution of the number of ratings per users (log scale)')
plt.xlabel('Number of ratings (log scale)')
plt.ylabel('Number of users')
plt.legend()
plt.show()

# %% [markdown]
# To chg
#
# **Comment :** Some users rate more than 20'000 reviews! However, the majority of them rate only a few beers
#
# **Explanation :**

# %% [markdown]
# **3.2 Are raters also writers? Check nbr of reviews compared to nbr of ratings**

# %%
missing_values_text_ba = (user_ratings_ba['review'] == False).sum() 
missing_values_text_ba_perc = 100 * missing_values_text_ba / user_ratings_ba.shape[0]

# %%
missing_values_text_rb = user_ratings_rb['text'].isna().sum()
missing_values_text_rb_perc = 100 *missing_values_text_rb / user_ratings_rb.shape[0]

# %%
print(f'We have {missing_values_text_ba} ratings without reviews in BeerAdvocate representing {missing_values_text_ba_perc:.2f}% of the total number of ratings')
print(f'We have {missing_values_text_rb} ratings without reviews in RateBeer representing {missing_values_text_rb_perc:.2f}% of the total number of ratings')
# Out:
# We have 5398276 ratings without reviews in BeerAdvocate representing 68.40% of the total number of ratings
# We have 379 ratings without reviews in RateBeer representing 0.01% of the total number of ratings

# %% [markdown]
# **Comment :** For RateBeer, almost all the ratings have a corresponding review, while many raters on BeerAdvocate did not gave their opinion

# %% [markdown]
# **3.3 New column: country, to remove states in USA**

# %%
def extract_country(location):
    if ',' in location:
        # If there is a comma in the location, split the string and take the first part
        return location.split(',')[0].strip()
    else:
        # If there is no comma, return the original location
        return location.strip()

# %%
user_ratings_ba['country'] = user_ratings_ba['location'].apply(extract_country)
user_ratings_rb['country'] = user_ratings_rb['location'].apply(extract_country)

# %% [markdown]
# **3.4 Plot contribution of different countries in the % of ratings in Beer Advocate and RateBeer**

# %%
by_country_ba = (user_ratings_ba.groupby('country')['rating'].count()*100 / user_ratings_ba.shape[0]).sort_values(ascending=False)
by_country_rb = (user_ratings_rb.groupby('country')['rating'].count()*100 / user_ratings_rb.shape[0]).sort_values(ascending =False)
top_20_countries_ba = by_country_ba.nlargest(20)
top_20_countries_rb = by_country_rb.nlargest(20)

# %%
figure, axes = plt.subplots(nrows=1, ncols=2, figsize = (14,5), sharey = True)

top_20_countries_ba.plot(kind='bar', ax = axes[0])
axes[0].set_xlabel('Countries')
axes[0].set_ylabel('% Ratings')
axes[0].set_title('Countries with highest % of ratings BeerAdvocate')

top_20_countries_rb.plot(kind='bar', ax = axes[1])
axes[1].set_xlabel('Countries')
axes[1].set_title('Countries with highest % of ratings RateBeer')

for ax in axes:
    ax.grid()

plt.tight_layout()
plt.show()

# %%
# DataFrames with precise values
df_ba = pd.DataFrame({'Country': top_20_countries_ba.index, '% of Ratings (BeerAdvocate)': top_20_countries_ba.values})
df_rb = pd.DataFrame({'Country': top_20_countries_rb.index, '% of Ratings (RateBeer)': top_20_countries_rb.values})

# Concatenate the two DataFrames along the columns axis
merged_df = pd.concat([df_ba, df_rb], axis=1)
merged_df
# Out:
#           Country  % of Ratings (BeerAdvocate)        Country  \
# 0   United States                    92.538929  United States
# 1          Canada                     3.478026        Denmark
# 2         England                     0.527028         Canada
# 3       Australia                     0.442368        England
# 4          Sweden                     0.379006         Sweden
# 5     Netherlands                     0.290798    Netherlands
# 6         Germany                     0.221216        Germany
# 7         Romania                     0.213145         Norway
# 8         Belgium                     0.208774        Finland
# 9          Russia                     0.133299         Poland
# 10          Spain                     0.121441        Belgium
# 11         Brazil                     0.109315      Australia
# 12       Scotland                     0.093529       Scotland
# 13         Panama                     0.090298          Italy
# 14         Mexico                     0.082354          Spain
# 15        Ireland                     0.078642        Estonia
# 16          Japan                     0.077932         France
# 17         France                     0.077730          Japan
# 18          Italy                     0.075132        Croatia
# 19       Thailand                     0.052200         Israel
#
#     % of Ratings (RateBeer)
# 0                 44.926574
# 1                  8.409938
# 2                  7.553272
# 3                  6.370527
# 4                  4.096177
# 5                  3.377718
# 6                  3.161723
# 7                  3.134238
# 8                  2.773087
# 9                  2.231056
# 10                 1.794024
# 11                 1.442496
# 12                 1.437901
# 13                 0.825972
# 14                 0.812605
# 15                 0.760973
# 16                 0.518346
# 17                 0.479517
# 18                 0.464806
# 19                 0.450746

# %% [markdown]
# **Comments :** Almost all the ratings in the BeerAdvocate data come from the United States (92.54%), whereas the United States contributes only half of the ratings in the RateBeer data (44.93%). The remaining half is distributed fairly equally around the world.

# %% [markdown]
# **3.5 Mapping of ratings -> for a better vizualization**

# %%
def get_coordinates(country):
    # Initialize a geolocator using Nominatim with a specific user_agent
    geolocator = Nominatim(user_agent="geoapiExercices")
    try:
        # obtain the location (latitude and longitude) for the given country
        location = geolocator.geocode(country, language='en')
        return (location.latitude,location.longitude)
    except:
        return (None,None)

# %%
def plot_map_ratings (user_ratings):
    # Count the number of ratings for each country
    country_counts = user_ratings['country'].value_counts().reset_index()
    # Rename columns
    country_counts.columns = ['country', 'nbr_ratings']
    # Add a new column 'Coordinates'
    country_counts['Coordinates'] = country_counts['country'].apply(get_coordinates)
    # Initialize a Folium map with an initial center at latitude 0 and longitude 0
    m = folium.Map(location=[0,0],zoom_start=2)
    
    # Iterate over each row in the country_counts dataFrame
    for _, row in country_counts.iterrows():
        # Check if coordinates for the country are available
        if row['Coordinates'][0] is not None:
            # Add a Circle marker to the map for each country
            folium.Circle(
                location= row['Coordinates'],
                radius= row['nbr_ratings'],
                color= 'crimson',
                fill= True,
                fill_color= 'crimson',
                popup='{}: {} ratings'.format(row['country'], row['nbr_ratings'])
            ).add_to(m)
            
    return m

# %%
display(plot_map_ratings(user_ratings_ba))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f09e5d63999d3681f5fa6082b0e198e4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f09e5d63999d3681f5fa6082b0e198e4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f09e5d63999d3681f5fa6082b0e198e4 = L.map(
#                 &quot;map_f09e5d63999d3681f5fa6082b0e198e4&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_82e3d674ab162386c0a82e1bc654908c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_82e3d674ab162386c0a82e1bc654908c.addTo(map_f09e5d63999d3681f5fa6082b0e198e4);
#
#             var circle_92a328a51c8fd7f73dd001bbaa1cb753 = L.circle(
#                 [39.7837304, -100.445882],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7303870, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f09e5d63999d3681f5fa6082b0e198e4);
#
#
#         var popup_ae939e83f27cbcd279b7a59aa240a6e1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6b88a35fc9735d77d51edb4780ac116a = $(`&lt;div id=&quot;html_6b88a35fc9735d77d51edb4780ac116a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;United States: 7303870 ratings&lt;/div&gt;`)[0];
#                 popup_ae939e83f27cbcd279b7a59aa240a6e1.setContent(html_6b88a35fc9735d77d51edb4780ac116a);
#
#
#
#         circle_92a328a51c8fd7f73dd001bbaa1cb753.bindPopup(popup_ae939e83f27cbcd279b7a59aa240a6e1)
#         ;
#
#
#
#
#             var circle_bd604389de663079d098d95c002dcfb2 = L.circle(
#                 [61.0666922, -107.991707],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 274512, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f09e5d63999d3681f5fa6082b0e198e4);
#
#
#         var popup_4bcf8e4e155a103af3f655a16523f71b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_de70f455b8fa21c3908ca0add72e18ed = $(`&lt;div id=&quot;html_de70f455b8fa21c3908ca0add72e18ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Canada: 274512 ratings&lt;/div&gt;`)[0];
#                 popup_4bcf8e4e155a103af3f655a16523f71b.setContent(html_de70f455b8fa21c3908ca0add72e18ed);
#
#
#
#         circle_bd604389de663079d098d95c002dcfb2.bindPopup(popup_4bcf8e4e155a103af3f655a16523f71b)
#         ;
#
#
#
#
#             var circle_f16166df60fc2e727694f1b0425c3256 = L.circle(
#                 [52.5310214, -1.2649062],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 41597, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f09e5d63999d3681f5fa6082b0e198e4);
#
#
#         var popup_00f051f3933266d986c9c0c8a57897ba = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_be955c0c73a1872e018f46b3329850b1 = $(`&lt;div id=&quot;html_be955c0c73a1872e018f46b3329850b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;England: 41597 ratings&lt;/div&gt;`)[0];
#                 popup_00f051f3933266d986c9c0c8a57897ba.setContent(html_be955c0c73a1872e018f46b3329850b1);
#
#
#
#         circle_f16166df60fc2e727694f1b0425c3256.bindPopup(popup_00f051f3933266d986c9c0c8a57897ba)
#         ;
#
#
#
#
#             var circle_578e376844cb074f5f1999bf9dbb0a1f = L.circle(
#                 [-24.7761086, 134.755],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: nul

# %%
display(plot_map_ratings(user_ratings_rb))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b7db292ef7453a16bd26e3815112e9ff {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b7db292ef7453a16bd26e3815112e9ff&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b7db292ef7453a16bd26e3815112e9ff = L.map(
#                 &quot;map_b7db292ef7453a16bd26e3815112e9ff&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4b1cc163be44be6a6945a988b72692aa = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_4b1cc163be44be6a6945a988b72692aa.addTo(map_b7db292ef7453a16bd26e3815112e9ff);
#
#             var circle_a7204d1a65b451eb1bdb872ecff9ec7b = L.circle(
#                 [39.7837304, -100.445882],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3108958, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b7db292ef7453a16bd26e3815112e9ff);
#
#
#         var popup_1baa00cd93ac9431aea0ff0c6fe059f7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_89b1c39258f4224bd348991c45728510 = $(`&lt;div id=&quot;html_89b1c39258f4224bd348991c45728510&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;United States: 3108958 ratings&lt;/div&gt;`)[0];
#                 popup_1baa00cd93ac9431aea0ff0c6fe059f7.setContent(html_89b1c39258f4224bd348991c45728510);
#
#
#
#         circle_a7204d1a65b451eb1bdb872ecff9ec7b.bindPopup(popup_1baa00cd93ac9431aea0ff0c6fe059f7)
#         ;
#
#
#
#
#             var circle_406af2a72ae1ced5cdf4959df3a56653 = L.circle(
#                 [55.670249, 10.3333283],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 581975, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b7db292ef7453a16bd26e3815112e9ff);
#
#
#         var popup_e1c01369d919147a8d94a565ed58fe1c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8f638b555d69c1b6504dc4143940ebaf = $(`&lt;div id=&quot;html_8f638b555d69c1b6504dc4143940ebaf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Denmark: 581975 ratings&lt;/div&gt;`)[0];
#                 popup_e1c01369d919147a8d94a565ed58fe1c.setContent(html_8f638b555d69c1b6504dc4143940ebaf);
#
#
#
#         circle_406af2a72ae1ced5cdf4959df3a56653.bindPopup(popup_e1c01369d919147a8d94a565ed58fe1c)
#         ;
#
#
#
#
#             var circle_b90072384550ee672554d8429819decf = L.circle(
#                 [61.0666922, -107.991707],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 522693, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b7db292ef7453a16bd26e3815112e9ff);
#
#
#         var popup_346eb9bce685c8275202577ddc907ec1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a8cbfd1dcb549e4eb8ee83ddc1be4b3a = $(`&lt;div id=&quot;html_a8cbfd1dcb549e4eb8ee83ddc1be4b3a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Canada: 522693 ratings&lt;/div&gt;`)[0];
#                 popup_346eb9bce685c8275202577ddc907ec1.setContent(html_a8cbfd1dcb549e4eb8ee83ddc1be4b3a);
#
#
#
#         circle_b90072384550ee672554d8429819decf.bindPopup(popup_346eb9bce685c8275202577ddc907ec1)
#         ;
#
#
#
#
#             var circle_9d7001a1c5202d1236b5a987981284ad = L.circle(
#                 [52.5310214, -1.2649062],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;:

# %% [markdown]
# **Comments :** As mentioned earlier, the USA constitutes the majority of ratings on BeerAdvocate and accounts for half of the entire dataset on RateBeer. Additionally, countries in Europe show increased activity in terms of ratings on RateBeer.

# %% [markdown]
# **3.6 What is the most rated style the whole world ?**

# %%
# in RateBeer
beer_style_counts = user_ratings_rb.groupby('style')['style'].agg('count')
beer_style_counts = beer_style_counts.sort_values (ascending=False)
top_20_beer_style = beer_style_counts.head(20)

# in BeerAdvocate
beer_style_counts_ba = user_ratings_ba.groupby('style')['style'].agg('count')
beer_style_counts_ba = beer_style_counts_ba.sort_values (ascending=False)
top_20_beer_style_ba = beer_style_counts_ba.head(20)

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Plotting the first bar chart for RateBeer
axes[0].bar(top_20_beer_style.index, top_20_beer_style.values)
axes[0].set_xlabel('Style')
axes[0].set_ylabel('Rating Count')
axes[0].set_title('Top 20 Most Rated Beer Styles in RateBeer')
axes[0].tick_params(axis='x', rotation=90)

# Plotting the second bar chart for BeerAdvocate
axes[1].bar(top_20_beer_style_ba.index, top_20_beer_style_ba.values, color = 'g')
axes[1].set_xlabel('Style')
axes[1].set_ylabel('Rating Count')
axes[1].set_title('Top 20 Most Rated Beer Styles in BeerAdvocate')
axes[1].tick_params(axis='x', rotation=90)

# Adjust layout for better spacing
plt.tight_layout()

plt.show()

# %% [markdown]
# **What about, especially in the ***US***? (as it constitutes the majority of the ratings in both datasets)**

# %%
# in RateBeer 
beer_style_counts_rb_us = user_ratings_rb[user_ratings_rb['country'] == 'United States'].groupby('style')['style'].agg('count')
beer_style_counts_rb_us = beer_style_counts_rb_us.sort_values (ascending=False)
top_20_beer_style_rb_us = beer_style_counts_rb_us.head(20)

# in BeerAdvocate
beer_style_counts_ba_us = user_ratings_ba[user_ratings_ba['country'] == 'United States'].groupby('style')['style'].agg('count')
beer_style_counts_ba_us = beer_style_counts_ba_us.sort_values (ascending=False)
top_20_beer_style_ba_us = beer_style_counts_ba_us.head(20)

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Plotting the first bar chart for RateBeer
axes[0].bar(top_20_beer_style_rb_us.index, top_20_beer_style_rb_us.values, color='skyblue')
axes[0].set_xlabel('Style')
axes[0].set_ylabel('Rating Count')
axes[0].set_title('Top 20 Most Rated Beer Styles in RateBeer IN USA')
axes[0].tick_params(axis='x', rotation=90)

# Plotting the second bar chart for BeerAdvocate
axes[1].bar(top_20_beer_style_ba_us.index, top_20_beer_style_ba_us.values,color='lightgreen')
axes[1].set_xlabel('Style')
axes[1].set_ylabel('Rating Count')
axes[1].set_title('Top 20 Most Rated Beer Styles in BeerAdvocate IN USA')
axes[1].tick_params(axis='x', rotation=90)

# Adjust layout for better spacing
plt.tight_layout()

plt.show()

# %% [markdown]
# **Comments :**
# 1. Some corresponding styles on both websites do not have exactly the same names. For example, we observe different types of IPA on *RateBeer*, such as 'India Pale Ale' and 'Imperial IPA,' while on *BeerAdvocate*, we find 'American IPA' and 'American Double / Imperial IPA'.
#
# This discrepancy could make merging them challenging.
#
# 2. The top 12 beer styles worldwide are consistent with the most-rated styles in the USA when researching the *BeerAdvocate* dataset, as opposed to *RateBeer* where the similarity extends only to the top 2 styles.
#
# Research on a global scale using *BeerAdvocate* may be biased due to its substantial amount of data from the USA.

# %% [markdown]
# **3.7 Supervised Learning : the relation between the features (*appearance, aroma, palate, taste, overall*) and response (*rating*)**

# %%
feature_cols = ['appearance', 'aroma','palate', 'taste', 'overall']

# %%
lin_reg = LinearRegression()  # create the model

# %%
#  check how many rows contain 'NaN' (missing values) in specific columns ('feature_cols') of a dataset
user_ratings_ba[feature_cols].isna().any(axis=1).sum()
# Out:
# 3330980

# %%
user_ratings_rb_f_cols = user_ratings_rb.dropna(subset = feature_cols)
X_rb = user_ratings_rb_f_cols[feature_cols]
y_rb = user_ratings_rb_f_cols.rating

lin_reg.fit(X_rb, y_rb)  # train it

print('Value of rating in RateBeer is calculted by this following formula :')
for f in range(len(feature_cols)):
    print("{0} * {1} + ".format(lin_reg.coef_[f], feature_cols[f]))
print(lin_reg.intercept_)
# Out:
# Value of rating in RateBeer is calculted by this following formula :
# 0.09999945877735729 * appearance +
# 0.0999994249812339 * aroma +
# 0.10000022230188373 * palate +
# 0.10000022586693079 * taste +
# 0.10000010919534569 * overall +
# 2.186165288797781e-06

# %%
user_ratings_ba_f_cols = user_ratings_ba.dropna(subset = feature_cols)
X_ba = user_ratings_ba_f_cols[feature_cols]
y_ba = user_ratings_ba_f_cols.rating

lin_reg.fit(X_ba, y_ba)  # train it

print('Value of rating in BeerAdvocate is calculted by this following formula :')
for f in range(len(feature_cols)):
    print("{0} * {1} + ".format(lin_reg.coef_[f], feature_cols[f]))
print(lin_reg.intercept_)
# Out:
# Value of rating in BeerAdvocate is calculted by this following formula :
# 0.060127936074310405 * appearance +
# 0.24014376071374843 * aroma +
# 0.10009737042022443 * palate +
# 0.40011606456338655 * taste +
# 0.19982273925031208 * overall +
# 4.3855366540501706e-05

# %% [markdown]
# **Comment :** The calculation of the rating value differs across sites.
#
# *RateBeer* assigns equal weights (~0.1 each) to calculate the rating score, distributing them uniformly among the criteria.
#
# In contrast, *BeerAdvocate* places varying degrees of importance on each criterion :
# - Taste ~0.4
# - Aroma ~0.24
# - Overall ~0.19
# - Palate ~0.10
# - Appearance ~0.06

# %% [markdown]
# **3.8 Do we have users in common for both datasets?**

# %%
# Merge the dataFrames 'users_ba' and 'users_rb' based on the 'user_name' column with an inner join
# The resulting DataFrame will contain only the rows where 'user_name' is common in both dataFrames
matched_users = pd.merge(users_ba, users_rb, on='user_name', how='inner')
display(matched_users)
# Out:
#       nbr_ratings_x  nbr_reviews              user_id_x       user_name  \
# 0              7820          465         nmann08.184925         nmann08
# 1              1866           23  rochefortchris.697017  RochefortChris
# 2              6306         6306          brentk56.6284        brentk56
# 3              6260         4734        emerge077.17949       emerge077
# 4              1851           10          buckyp.435592          buckyp
# ...             ...          ...                    ...             ...
# 4344              1            1         cannile.407676         Cannile
# 4345              1            0    nogbadthebad.845220    NogbadTheBad
# 4346              5            0       pagail118.566707       pagail118
# 4347              1            1         brewfeller.850      brewfeller
# 4348              1            1   breathinghope.249088   breathinghope
#
#           joined_x                     location_x  nbr_ratings_y  user_id_y  \
# 0     1.199704e+09      United States, Washington              3     101495
# 1     1.349172e+09  United States, North Carolina              8     213410
# 2     1.084442e+09  United States, North Carolina              1      26838
# 3     1.113646e+09        United States, Illinois             40      46216
# 4     1.267960e+09  United States, South Carolina             20      68888
# ...            ...                            ...            ...        ...
# 4344           NaN                            NaN             11      45381
# 4345  1.408010e+09                            NaN              7     217518
# 4346  1.297595e+09                         Canada              1     118648
# 4347  1.033812e+09        United States, Oklahoma              1      82734
# 4348  1.221214e+09            United States, Ohio              1      88915
#
#           joined_y                     location_y
# 0     1.265800e+09      United States, Washington
# 1     1.345975e+09  United States, South Carolina
# 2     1.125742e+09  United States, North Carolina
# 3     1.165576e+09        United States, Illinois
# 4     1.201864e+09         United States, Georgia
# ...            ...                            ...
# 4344  1.164020e+09      United States, California
# 4345  1.347876e+09   United States, Massachusetts
# 4346  1.291720e+09                         Canada
# 4347  1.223460e+09        United States, Oklahoma
# 4348  1.237374e+09            United States, Ohio
#
# [4349 rows x 10 columns]

# %% [markdown]
# **Comment :** We have raters which are the same for both datasets. It could be a problem for a potential merge, but we can remove them. However, it is probable that someone reviews on the both website with different usernames, and we have no way to identify them. It is another arguent to avoid merging the datasets

# %% [markdown]
# >During the comparison of the *BeerAdvocate* and *RateBeer* datasets, we observed several critical points:
# > - More than half (69.15%) of the total number of ratings on BeerAdvocate do not contain reviews, as opposed to 0.01% on RateBeer (see 3.2).
# >- The majority of ratings come from the USA (see 3.4, 3.5).
# >- Some corresponding beer styles on both websites do not have exactly the same names (see 3.6).
# >- They have different methods for computing ratings based on their criteria, with BeerAdvocate placing more importance on 'taste' evaluation than 'appearance' (see 3.7).
# >- Only a small community of users is subscribed to both sites (see 3.8).
#
# >Even though we found a small community of users subscribed to both websites (4,349 users in common), due to the unequal distribution of ratings worldwide (90% in the USA for BeerAdvocate and 44% in the USA for RateBeer) and the differences in beer style names and rating computation methods, merging these two datasets seems very challenging.
#
# >Therefore, keeping in mind that each dataset has its own pros and cons for obtaining specific information, the following exploration will be based on the ***RateBeer*** dataset, which has a more evenly distributed number of ratings across the world. However, we will tailor our research based on the specific information we require, determining which dataset is more suitable for our needs and adapting our observations (such as the way of calculating the rating score, review quality, etc.)

# %% [markdown]
# ## 4. Exploration of the dataset RateBeer: Seasonal tendencies?

# %% [markdown]
# To ensure that our project is feasible to main goal is to find seasonal pattern amongst beers of the dataset in terms on popularity. To find those pattern we will apply the "Seasonal and Trend decomposition using Loess" (STL) method to the evolution of the number of ratings for different popular style of  beers. The STL method decompose a temporal series in 3 components : seasonal, trend and residuals. It's a outliers robust method that allows a clear visualisation of the evolution of the number of ratings.

# %% [markdown]
# **4. 1 Distribution of ratings per month for all beers**

# %%
# filter the dataframe information from [01/01/2010;31/12/2016]
all_beer_all_world_rb = user_ratings_rb[
    (user_ratings_rb['year'] >= 2010) &
    (user_ratings_rb['year'] <= 2016)
]

# %%
all_beer_ratings_all_world_rb = all_beer_all_world_rb.groupby('year_month')["rating"].count()

# %%
plt.figure(figsize = (14,4))
plt.plot(all_beer_ratings_all_world_rb.index.astype(str), all_beer_ratings_all_world_rb.values, marker = 'o', color = 'blue')
plt.xlabel('Month')
plt.ylabel('Number of ratings ')
plt.title('All beer styles (RateBeer)')
plt.xticks(rotation = 90)
#plt.ylim(0,75000)
plt.show()

# %% [markdown]
# **Comments :**

# %% [markdown]
# **4.2 Distribution of IPA reviews normalized according to total number of reviews**

# %%
def plot_STL(ratings_per_month, type):
    # Message from shu, ca je l'ai enleve car si tu appelles 2 fois cette focntion ca marche plus
    # ratings_per_month.index = ratings_per_month.index.to_timestamp()

    # Apply Seasonal-Trend decomposition using LOESS (STL)
    stl = STL(ratings_per_month, seasonal=13, period=12)
    result = stl.fit() # fit the model

    # Extract components from the decomposition
    trend = result.trend
    seasonal = result.seasonal
    residual = result.resid

    # Create 4 subplot figure
    plt.figure(figsize=(10, 6))

    # Subplot 1: Trend
    plt.subplot(411)
    plt.plot(trend, label='Trend', color = type)
    plt.legend(loc='best')

    # Subplot 2: Seasonality
    plt.subplot(412)
    plt.plot(seasonal,label='Seasonality', color = type)
    plt.legend(loc='best')

    # Subplot 3: Residuals
    plt.subplot(413)
    plt.plot(residual, label='Residuals', color = type)
    plt.legend(loc='best')
    plt.tight_layout()

# %%
ipa_all_world_rb = all_beer_all_world_rb[(all_beer_all_world_rb['style'] == 'India Pale Ale (IPA)')]
ipa_ratings_per_month_all_world_rb = ipa_all_world_rb.groupby('year_month')["rating"].count()
ipa_ratings_perc_rb = ipa_ratings_per_month_all_world_rb / all_beer_ratings_all_world_rb

# Convert the index to timestamp
ipa_ratings_per_month_all_world_rb.index = ipa_ratings_per_month_all_world_rb.index.to_timestamp()

# %%
plt.figure(figsize = (14,4))
plt.plot(ipa_ratings_perc_rb.index.astype(str), ipa_ratings_perc_rb.values, marker = 'o', color = 'orange')
plt.xlabel('Month')
plt.ylabel('% of ratings relative to total ratings')
plt.title('IPA (RateBeer)')
plt.xticks(rotation = 90)
plt.show()
plot_STL(ipa_ratings_per_month_all_world_rb, 'orange')

# %% [markdown]
# Four graphs are displayed: the first one is the evolution of the number of ratings relative to total ratings of the IPA beers from January 2010 and December 2016. The second one is the trend of the first graph found by the STL algorithm. The third one represents the seasonality of the first graph found by the STL algorithm. The fourth one is the residuals  of the first graph found by the STL algorithm. The first plot gives us some insights about the popularity of IPAs although it's not clear. The 3 remaining graphs gives more meaningfull insight about the data. The trend plot shows that there is a constant increase in popularity. The third graph gives the most interesting insight. The pattern becomes very clear in 2012. There is a clear decrease in popularity in winter that start in the middle of autumn and it becomes very popular in spring and in summer. The residuals graph gives the information that the pattern found are meaningfull. As the range of the residuals is smaller than the seasonality graph it means that there is not much noise and that the pattern found is meaningfull.

# %% [markdown]
# **Same thing for Pilsener**

# %%
pilsener = all_beer_all_world_rb[(all_beer_all_world_rb['style'] == 'Pilsener')]
pilsener_per_month_all_world_rb = pilsener.groupby('year_month')["rating"].count()
pilsener_ratings_perc_rb = pilsener_per_month_all_world_rb / all_beer_ratings_all_world_rb

# Convert the index to timestamp
pilsener_per_month_all_world_rb.index = pilsener_per_month_all_world_rb.index.to_timestamp()

# %%
plt.figure(figsize = (14,4))
#plt.plot(pilsener_ratings_per_month.index.astype(str), pilsener_ratings_per_month.values, marker = 'o')
plt.plot(pilsener_ratings_perc_rb.index.astype(str), pilsener_ratings_perc_rb.values, marker = 'o', color = 'lightblue')
plt.xlabel('Month')
plt.ylabel('% of ratings relative to total ratings')
plt.title('Pilsener (blond) (RateBeer)')
plt.xticks(rotation = 90)
plt.show()
plot_STL(pilsener_per_month_all_world_rb, 'lightblue')

# %% [markdown]
# As the plots for the IPAs, we see that for the pilsener beers there is a rather constant increase in popularity before it becomes constant in 2014. The seasonality graph gives a clear pattern,september is the time where it's the most popular and december is the time where it's the least popular. The residuals plot shows that the result of the seasonality plot is meaningfull.

# %% [markdown]
# **Belgian Strong Ale**

# %%
belg_strong_ale_rb = all_beer_all_world_rb[(all_beer_all_world_rb['style'] == 'Belgian Strong Ale')]
belg_strong_ale_per_month_all_world_rb = belg_strong_ale_rb.groupby('year_month')["rating"].count()
belg_strong_ale_ratings_perc_rb = belg_strong_ale_per_month_all_world_rb / all_beer_ratings_all_world_rb

# Convert the index to timestamp
belg_strong_ale_per_month_all_world_rb.index = belg_strong_ale_per_month_all_world_rb.index.to_timestamp()

# %%
plt.figure(figsize = (14,4))
#plt.plot(belg_strong_ale_ratings_per_month.index.astype(str), belg_strong_ale_ratings_per_month.values, marker = 'o')
plt.plot(belg_strong_ale_ratings_perc_rb.index.astype(str), belg_strong_ale_ratings_perc_rb.values, marker = 'o', color = 'lightgreen')
plt.xlabel('Month')
plt.ylabel('Number of ratings')
plt.title('Belgian Strong Ale (RateBeer)')
plt.xticks(rotation = 90)
plt.show()
plot_STL(belg_strong_ale_per_month_all_world_rb, 'lightgreen')

# %% [markdown]
# The trend plot shows that the popularity of the Belgian strong ale (BSA) increase from 2010 until the end of 2013 and decrease from that moment. The seasonality plot shows a clear pattern. On the opposite of the the IPA and the pilsener, the BSA becomes very popular every december. Although, the range of the residuals values is closer to the range of the range of seasonality plot values the pattern found relates to the original plot. It allows to say that the result is meaningfull.

# %% [markdown]
# We see that the pattern found are different between different style of beers but it would be interesting to understand the causes of those differences to ensure that those pattern are not random. One of the characteristics that is interesting to see to ensure that, is to look at the difference of alcohol percentage in those beer styles.

# %% [markdown]
# **4.3 Distribution of alcohol degree among beers compared to ratings -> do people drink a lot of strong beers?**

# %%
beers_less_15_rb = beers_rb[beers_rb['abv'] <= 15]

# %%
pils = beers_less_15_rb[beers_less_15_rb['style'] == 'Pilsener']
bsa = beers_less_15_rb[beers_less_15_rb['style'] == 'Belgian Strong Ale']

# %%
pils.head()
# Out:
#      beer_id                        beer_name  brewery_id  \
# 55    526621                 Boundary Generic       22818
# 214   360989     Mourne Mountains Mourne Mist       23165
# 255   368965                Walled City Kicks       24866
# 303   457548  AdstraGold Oaky Pilsner Premium       15008
# 304   224981       AdstraGold Pilsner Premium       15008
#
#                              brewery_name     style  nbr_ratings  \
# 55                               Boundary  Pilsener            1
# 214              Mourne Mountains Brewery  Pilsener            1
# 255                           Walled City  Pilsener            1
# 303  AdstraGold Microbrewery & Bistro Bar  Pilsener            2
# 304  AdstraGold Microbrewery & Bistro Bar  Pilsener            5
#
#      overall_score  style_score   avg  abv  avg_computed    zscore  \
# 55             NaN          NaN  2.89  5.0          2.80       NaN
# 214            NaN          NaN  3.00  4.5          3.30 -0.412028
# 255            NaN          NaN  3.00  4.1          3.30       NaN
# 303            NaN          NaN  2.81  3.5          2.60       NaN
# 304            NaN          NaN  2.78  3.0          2.22       NaN
#
#      nbr_matched_valid_ratings  avg_matched_valid_ratings
# 55                           0                        NaN
# 214                          1                        3.3
# 255                          0                        NaN
# 303                          0                        NaN
# 304                          0                        NaN

# %%
plt.figure(figsize = (8,6))
plt.hist(pils['abv'], bins = 30, color = 'blue', label = 'Pilsener', density = True, alpha = 0.5, edgecolor = 'black')
plt.hist(bsa['abv'], bins = 30, color = 'orange', label = 'Belgian Strong Ale', density = True, alpha = 0.5, edgecolor = 'black')
plt.xlabel('Alcohol by Volume')
plt.ylabel('Frequency')
plt.title('Distribution of alcohol degree (RateBeer)')
plt.xlim(0,15)
plt.legend()
plt.show()

# %% [markdown]
# We see with that plot, that, there is a huge difference in the distribution of alcohol degree between the BSA and the pilsener. The BSA are more strong than the pilsener. Therefore there is a potential cause of the difference of patterns between those beers. We can make the hypothesis that people tend to drink beers with a high degree of alcohol in winter and that people drink lighter beer in spring and summer. We would need to analyse further to either confirm or infirm this statement.

# %%
plt.figure(figsize=(8, 6))  # Adjust the figure size as needed
plt.boxplot([pils['abv'], bsa['abv']], labels=['Pilsener', 'Belgian Strong Ale'])
plt.title('Distribution of alcohol degree (RateBeer)')
plt.xlabel('ABV (Alcohol By Volume)')
plt.show()

# %%
top_5_beers = top_20_beer_style_ba.index[:5]
print(top_5_beers)
filtered_data = user_ratings_ba[user_ratings_ba['style'].isin(top_5_beers)]
filtered_data = filtered_data[filtered_data['date'].dt.year >= 2009]


# Regrouper les données par mois et compter le nombre de notations par mois
monthly_counts = filtered_data.groupby('month').size()

fig, axes = plt.subplots(nrows=5, ncols=1, figsize=(10, 20), dpi=100)

# Customizing the aesthetics as per the provided example
plt.style.use('dark_background')

# Looping over each style and plotting it on its own subplot
for i, style in enumerate(top_5_beers):
    # Group data by 'year_month' and sum the 'nbr_ratings' for each group
    time_data = filtered_data[filtered_data['style'] == style].groupby('year_month')['nbr_ratings'].sum()
    # Plotting the data
    ax = axes[i]
    ax.plot(time_data.index.astype(str), time_data.values, color='gold', marker='o')
    
    # Setting the title for each subplot
    ax.set_title(f'{style} Ratings Over Time')

    # Formatting the x-axis to show every other month for clarity
    ax.tick_params(axis='x', rotation=45)

    # Set y-label
    ax.set_ylabel('Number of Ratings')
    plot_STL(time_data)
# Adjusting layout to prevent overlap
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# Index(['American IPA', 'American Double / Imperial IPA',
#        'American Double / Imperial Stout', 'American Pale Ale (APA)',
#        'Saison / Farmhouse Ale'],
#       dtype='object', name='style')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[72], line 31
#      29     # Set y-label
#      30     ax.set_ylabel('Number of Ratings')
# ---> 31     plot_STL(time_data)
#      32 # Adjusting layout to prevent overlap
#      33 plt.tight_layout()
#
# TypeError: plot_STL() missing 1 required positional argument: 'type'
